# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 data.obstime data.ref_area  \
# 0           1   2007-05-01            AT
# 1           2   2007-06-01            AT
# 2           3   2007-07-01            AT
# 3           4   2007-08-01            AT
# 4           5   2007-09-01            AT
#
#                                           data.title  data.obsvalue
# 0  loans to corporations of up to EUR 1M (new bus...          933.0
# 1  loans to corporations of up to EUR 1M (new bus...         1099.0
# 2  loans to corporations of up to EUR 1M (new bus...         1162.0
# 3  loans to corporations of up to EUR 1M (new bus...          884.0
# 4  loans to corporations of up to EUR 1M (new bus...         1005.0

# %%
df.shape
# Out:
# (11922, 5)

# %%
df["data.obstime"].min()
# Out:
# '2005-01-01'

# %%
df["data.obstime"].max()
# Out:
# '2024-01-01'

# %%
df = df.set_index('Unnamed: 0')

# %%
df.columns = ["date","ref_area","title","obs_value"]

# %%
df.head()
# Out:
#                   date ref_area  \
# Unnamed: 0
# 1           2007-05-01       AT
# 2           2007-06-01       AT
# 3           2007-07-01       AT
# 4           2007-08-01       AT
# 5           2007-09-01       AT
#
#                                                         title  obs_value
# Unnamed: 0
# 1           loans to corporations of up to EUR 1M (new bus...      933.0
# 2           loans to corporations of up to EUR 1M (new bus...     1099.0
# 3           loans to corporations of up to EUR 1M (new bus...     1162.0
# 4           loans to corporations of up to EUR 1M (new bus...      884.0
# 5           loans to corporations of up to EUR 1M (new bus...     1005.0

# %%
df.isnull().sum(axis=0)
# Out:
# date           0
# ref_area       0
# title          0
# obs_value    835
# dtype: int64

# %% [markdown]
# "Which country has the most loans to corp over 1M"

# %%
sVars = np.unique(df.title)

# %%
df_ = df[df.title == 'loans to corporations of up to EUR 1M (new business)']
df_
# Out:
#                   date ref_area  \
# Unnamed: 0
# 1           2007-05-01       AT
# 2           2007-06-01       AT
# 3           2007-07-01       AT
# 4           2007-08-01       AT
# 5           2007-09-01       AT
# ...                ...      ...
# 7718        2023-08-01       U2
# 7719        2023-09-01       U2
# 7720        2023-10-01       U2
# 7721        2023-11-01       U2
# 7722        2023-12-01       U2
#
#                                                         title  obs_value
# Unnamed: 0
# 1           loans to corporations of up to EUR 1M (new bus...     933.00
# 2           loans to corporations of up to EUR 1M (new bus...    1099.00
# 3           loans to corporations of up to EUR 1M (new bus...    1162.00
# 4           loans to corporations of up to EUR 1M (new bus...     884.00
# 5           loans to corporations of up to EUR 1M (new bus...    1005.00
# ...                                                       ...        ...
# ...

# %%
df_["obs"] =

# %%
df_.isnull().sum(axis=0)
# Out:
# date           0
# ref_area       0
# title          0
# obs_value    353
# dtype: int64

# %%
df_.groupby(by=["ref_area"]).sum().sort_values("obs_value")
# Out:
# /var/folders/d6/3cp0f2_d3n5bhwwpxrw9v9nr0000gp/T/ipykernel_88244/652927561.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_.groupby(by=["ref_area"]).sum().sort_values("obs_value")
#             obs_value
# ref_area
# MT            3736.48
# LV            5374.74
# CY           11780.00
# LT           15552.37
# EE           16246.93
# SK           27768.56
# SI           37247.78
# GR           67033.00
# IE           89707.00
# FI          143669.00
# LU          185642.00
# AT          225323.00
# NL          290959.00
# PT          315345.03
# BE         1177860.00
# FR         1658570.00
# DE         2318371.00
# IT         2904820.00
# ES         3242574.00
# U2        12760395.57

# %%
df['missing'] = df["obs_value"].isnull()*1

# %%
df
# Out:
#                   date ref_area  \
# Unnamed: 0
# 1           2007-05-01       AT
# 2           2007-06-01       AT
# 3           2007-07-01       AT
# 4           2007-08-01       AT
# 5           2007-09-01       AT
# ...                ...      ...
# 11918       2023-09-01       U2
# 11919       2023-10-01       U2
# 11920       2023-11-01       U2
# 11921       2023-12-01       U2
# 11922       2024-01-01       U2
#
#                                                         title  obs_value  \
# Unnamed: 0
# 1           loans to corporations of up to EUR 1M (new bus...      933.0
# 2           loans to corporations of up to EUR 1M (new bus...     1099.0
# 3           loans to corporations of up to EUR 1M (new bus...     1162.0
# 4           loans to corporations of up to EUR 1M (new bus...      884.0
# 5           loans to corporations of up to EUR 1M (new bus...     1005.0
# ...                                                       ...        ...
# ...

# %%
df.groupby(by=["ref_area"]).mean().sort_values("obs_value")
# Out:
# /var/folders/d6/3cp0f2_d3n5bhwwpxrw9v9nr0000gp/T/ipykernel_88244/1017461712.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=["ref_area"]).mean().sort_values("obs_value")
#              obs_value   missing
# ref_area
# MT           35.354768  0.353333
# LV           74.842697  0.406667
# CY           80.386965  0.041045
# EE           98.458324  0.073379
# LT          117.225050  0.000000
# SI          263.686833  0.000000
# SK          296.334366  0.026667
# GR          436.290566  0.293333
# IE         1057.877000  0.000000
# PT         1060.655483  0.000000
# FI         1107.177667  0.000000
# LU         1545.969874  0.203333
# AT         2960.506333  0.000000
# NL         3706.461667  0.000000
# BE         8081.537333  0.000000
# FR         8697.331333  0.000000
# ...

# %%
gdf = df.groupby(by=["ref_area","title"]).mean()
gdf
# Out:
# /var/folders/d6/3cp0f2_d3n5bhwwpxrw9v9nr0000gp/T/ipykernel_88244/52367876.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gdf = df.groupby(by=["ref_area","title"]).mean()
#                                                                  obs_value  \
# ref_area title
# AT       HICP - Overall index                                     2.699000
#          loans to corporations of over EUR 1M (new busin...    7752.205000
#          loans to corporations of up to EUR 1M (new busi...    1126.615000
# BE       HICP - Overall index                                     2.417000
#          loans to corporations of over EUR 1M (new busin...   18352.895000
#          loans to corporations of up to EUR 1M (new busi...    5889.300000
# ...

# %%
df_imputed = df.copy()

# %%
sCountries = np.unique(df_imputed.ref_area)
sCountries
# Out:
# array(['AT', 'BE', 'CY', 'DE', 'EE', 'ES', 'FI', 'FR', 'GR', 'IE', 'IT',
#        'LT', 'LU', 'LV', 'MT', 'NL', 'PT', 'SI', 'SK', 'U2'], dtype=object)

# %%
sVars
# Out:
# array(['HICP - Overall index',
#        'loans to corporations of over EUR 1M (new business)',
#        'loans to corporations of up to EUR 1M (new business)'],
#       dtype=object)

# %%
for c in sCountries:
    for v in sVars:
        df_imputed.loc[ (df_imputed['missing']== 1) & 
                       (df_imputed.ref_area == c) & 
                       (df_imputed.title == v),'title'] = gdf.loc[(c,v),"obs_value"]

# %%
df_imputed.isnull().sum()
# Out:
# date           0
# ref_area       0
# title          0
# obs_value    835
# missing        0
# dtype: int64
